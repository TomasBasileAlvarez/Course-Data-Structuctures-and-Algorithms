# %% [markdown]
# # Bellman Ford
# Aqui calculamos la minima distancia en un grafo con pesos que pueden ser negativos. El dijsktra ya no sirve porque el paso en el que tomabamos el nodo con minimo dist porque ya lo confirmabamos ya no tiene sentido
# ![image.png](attachment:image.png)
#
# El algoritmo solo tiene sentido si no hay ciclos negativos (que al recorrerlos el valor neto sea negativo) porque en ese caso caemos en un ciclo que va vajando las distancias infinitamente. El algoritmo se parece mucho al que habiamos intentado como naive para grafos con pesos positivos y tiene un running time de O(|V||E|) <br>
#
# Un grafo G contiene un ciclo de peso negativo sii aplicar Bellman Ford adicionalmente cambia algun valor de dist

# %%
''' Exchange money optimalluy'''

#Uses python3
#import sys
#import queue

#Uses python2
import queue as Queue


def shortet_paths(adj, cost, s, distance, reachable, shortest):
    #write your code here
    distance[s] = 0
    reachable[s] = 1
    q = Queue.Queue()
    for i in range(len(adj)):
        for u in range(len(adj)):
            for v in adj[u]:
                v_index = adj[u].index(v)
                if distance[u] != 10**19 and distance[v] > distance[u] + cost[u][v_index]:
                    distance[v] = distance[u] + cost[u][v_index]
                    reachable[v] = 1
                    if i == len(adj) - 1:
                        q.put(v)

    visited = [0] * len(adj)
    while not q.empty():
        u = q.get()
        visited[u] = 1
        if u != s:
            shortest[u] = 0
        for v in adj[u]:
            if visited[v] == 0:
                q.put(v)
                visited[v] = 1
                shortest[v] = 0
    distance[s] = 0

if __name__ == '__main__':
    n, m = [int(x) for x in input().split()]
    adj = [[] for _ in range(n)]
    cost = [[] for _ in range(n)]
    for i in range(m):
        a, b, w = [int(x) for x in input().split()]
        adj[a - 1].append(b - 1)
        cost[a - 1].append(w)
    s = int(input())
    '''
    input = sys.stdin.read()
    data = list(map(int, input.split()))
    n, m = data[0:2]
    data = data[2:]
    edges = list(zip(zip(data[0:(3 * m):3], data[1:(3 * m):3]), data[2:(3 * m):3]))
    data = data[3 * m:]
    adj = [[] for _ in range(n)]
    cost = [[] for _ in range(n)]
    for ((a, b), w) in edges:
        adj[a - 1].append(b - 1)
        cost[a - 1].append(w)
    s = data[0]
    '''
    s -= 1
    distance = [10**19] * n
    reachable = [0] * n
    shortest = [1] * n
    shortet_paths(adj, cost, s, distance, reachable, shortest)
    for x in range(n):
        if reachable[x] == 0:
            print('*')
        elif shortest[x] == 0:
            print('-')
        else:
            print(distance[x])
# Out:
# dsf
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-e1f4e0d1b325> in <module>()
#      38
#      39 if __name__ == '__main__':
# ---> 40     n, m = [int(x) for x in input().split()]
#      41     adj = [[] for _ in range(n)]
#      42     cost = [[] for _ in range(n)]
#
# <ipython-input-1-e1f4e0d1b325> in <listcomp>(.0)
#      38
#      39 if __name__ == '__main__':
# ---> 40     n, m = [int(x) for x in input().split()]
#      41     adj = [[] for _ in range(n)]
#      42     cost = [[] for _ in range(n)]
#
# ValueError: invalid literal for int() with base 10: 'dsf'

# %%
''' Find negative cycle'''




    
def negative_cycle(adj, cost,w):
    #write your code here
    dist=[float('inf')]*len(adj)

    dist[w] = 0
    for i in range(len(adj)):
        for u in range(len(adj)):
            for v in adj[u]:
                v_index = adj[u].index(v)
                if dist[v] > dist[u] + cost[u][v_index]:
                    dist[v] = dist[u] + cost[u][v_index]
                    if i == len(adj) - 1:
                        return 1
    return 0
def DFS(adj, cost):
    for w in range(len(adj)):
        if negative_cycle(adj, cost, w) == 1:
            return 1
        return 0

if __name__ == '__main__':
    n, m = [int(x) for x in input().split()]
    adj = [[] for _ in range(n)]
    cost = [[] for _ in range(n)]
    for i in range(m):
        a, b, w = [int(x) for x in input().split()]
        adj[a - 1].append(b - 1)
        cost[a - 1].append(w)
    print(DFS(adj, cost))
    '''
    input = sys.stdin.read()
    data = list(map(int, input.split()))
    n, m = data[0:2]
    data = data[2:]
    edges = list(zip(zip(data[0:(3 * m):3], data[1:(3 * m):3]), data[2:(3 * m):3]))
    data = data[3 * m:]
    adj = [[] for _ in range(n)]
    cost = [[] for _ in range(n)]
    for ((a, b), w) in edges:
        adj[a - 1].append(b - 1)
        cost[a - 1].append(w)
    print(negative_cycle(adj, cost))
    '''
# Out:
# adfv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-7e978e685cd8> in <module>()
#      26
#      27 if __name__ == '__main__':
# ---> 28     n, m = [int(x) for x in input().split()]
#      29     adj = [[] for _ in range(n)]
#      30     cost = [[] for _ in range(n)]
#
# <ipython-input-2-7e978e685cd8> in <listcomp>(.0)
#      26
#      27 if __name__ == '__main__':
# ---> 28     n, m = [int(x) for x in input().split()]
#      29     adj = [[] for _ in range(n)]
#      30     cost = [[] for _ in range(n)]
#
# ValueError: invalid literal for int() with base 10: 'adfv'
