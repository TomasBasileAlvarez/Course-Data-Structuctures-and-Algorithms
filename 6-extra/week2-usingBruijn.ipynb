# %% [markdown]
# Hacer el algoritmo de la semana pasada para dna muy largo ser'ia muy compicado. <br>
# Por ello, se lleg'o a la idea de DNA Chip <br>
# En vez de generar varias lecturas de longitud de aprox 500 nucleotidos, lo que hacemos es genera todas las k-mers del genoma (para un g chiquito). <br><br>
# Algo como lo que sigue:
# ![image.png](attachment:image.png)
# Ah'i est'an los 3-meros del gen de arriba (aqu'i aparecen ordenados pero no tienen por qu'e estarlo). <br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Sin embargo, el principio de arriba no sirve siempre, porque tendremos que conectar muchos otros 3-meros y no s'olo los que se conectaron arriba. De hecho, si los ordenamos en algun otro orden, se puede ver algo as'i
# ![image.png](attachment:image.png)

# %% [markdown]
# Entonces, digamos que empezamos en TAA y vamos conectando. Sin embargo, en cada nodo tenemos varias opciones para conectar y lo que debemos de hacer es siguir un camino hamiltoniano (cada vertice una sola vez)
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Assembling Genome from k-mers
# Assmbling un genome a partir de sus k-mers es dificil porque si k es chiquito puede haber varios caminos validos en el grafo. <br> <br>
# Universal string.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Entonces, De bruijn definio las grafos con ejes.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Luego se le ocurrio una idea muy loca, pegar vertices con el mismo nombre.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Entonces, construir un deBruijn a partir de todos los k-meros consiste en poner como vertices a todos los k-1 cadenas de todos los prefijos o sufijos de los k-meros (sin repetir). Y luego ponemos como ejes a los k-meros que conectan el prefijo con el sufijo. <br>
# Eso nos da un grafo de deBrujin dado el conjunto de todos los k-meros. <br>
# Luego, dado este grafo de deBrujin tenemos que encontrar el genoma inicial, lo podemos hacer encontrando un camino euleriano en el grafo de debrujin.

# %% [markdown]
# # Euler Paths
# Caminar por un grafo tal que pasamos por cada eje una sola vez y regresamos al punto inicial.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Aunque parecen problemas muy similares, el de Euler es más fácil de resolver. <br>
# ##### Teorema de Euler
# ![image.png](attachment:image.png)
# Obviamente cada grafo euleriano es balanceado (porque hay que llegar a un grafo el mismo numero de veces que se sale). <br>
# Y se puede demostrar que todo grafo balanceado es Euleriano.

# %% [markdown]
# Dem: Primero observamos que si empezamos a caminar al azar en un grafo balanceado, es probable que nos quedemos atrapados, pero por ser balanceados, s'olo nos podemos quedar atrapados en el vertice inicial, es decir, todos los caminos hechos al azar van a ser ciclos cerrados
# ![image.png](attachment:image.png)
# Ahora lo que hay que hacer es pararnos en otro vertice del ciclo verde (uno con ejes sin explorar todav'ia), y ahora un camino es hacer primero el ciclo verde y luego explorar algo m'as en el eje sin explorar.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Al explorar de nuevo va a crear un nuevo ciclo (azul)
# ![image.png](attachment:image.png)
# Con eso ya alargamos los vertices estudiados

# %% [markdown]
# Ahora otravez tomamos un punto del ciclo con ejes sin visitar, lo recorremos completo (y regrezamos al punto inicial) y al terminar exploramos de nuevo.
# ![image.png](attachment:image.png)

# %% [markdown]
# Ah'i la hormiga hizo todo el ciclo azul+verde pero ahora puede seguir caminando y crear un nuevo ciclo
# ![image.png](attachment:image.png)

# %% [markdown]
# Sin embargo, este algoritmo no es el m'as r;apido, pues se puede hacer en un tiempo lineal.
